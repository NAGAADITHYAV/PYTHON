# %%
import requests

# %%
Headers = { 'Authorization': 'Bearer eyJraWQiOiJXTTZDLVEiLCJhbGciOiJFUzI1NiJ9.....twUpui5gUdTehL0V_DkqLF4fGqh_JDd3jVARvtQLJZEZZF3CQV0pk18RXYS7NmhDTqGJpexwc_tTy3febgURgQ' }

# %%
response = requests.get("https://groww.in/v1/api/aggregator/v1/insight/net_worth/fetch_graph_data/ALL", headers = Headers)

# %%
res = response.json()

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
x = []
y = []
for ep in res:
    x.append(ep['epoch'])
    y.append((ep['netWorth']-ep['investedAmount'])/ep['investedAmount'])

# %%
fig,ax = plt.subplots()
ax.plot(x,y)
